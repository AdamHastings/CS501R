# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from numpy import array, dot, random
from random import choice

def unpickle( file ):
    import cPickle
    fo = open(file, 'rb')
    dict = cPickle.load(fo)
    fo.close()
    return dict

data = unpickle( 'cifar-10-batches-py/data_batch_1' )

features = data['data']
labels = data['labels']
labels = np.atleast_2d( labels ).T




def conv( x, filter_size=3, stride=2, num_filters=64, is_output=False, name="conv" ):
    '''
    x is an input tensor
    Declare a name scope using the "name" parameter
    Within that scope:
      Create a W filter variable with the proper size
      Create a B bias variable with the proper size
      Convolve x with W by calling the tf.nn.conv2d function
      Add the bias
      If is_output is False,
        Call the tf.nn.relu function
      Return the final op
    ''' 
    pass
    with tf.name_scope("convolution") as scope:
        # Create a W filter variable wit the proper size
        W = tf.get_variable("W", None, dtype=float32, initializer=tf.random_normal([3, filter_size, filter_size, num_filters]))
        # Create a B bias varaible with the proper size
        B = tf.get_variable("B", None, dtype=float32, initializer=tf.random_normal([1,1,3,num_filters]))
        # Convolve x with W by calling the tf.nn.conv2d function
        conv = tf.nn.conv2d(input=x,filter=W,stride=2,padding="SAME")
        # Add the bias
        biased = conv + B;  #Does this work?
        # If is_output is False
        if (is_output == False):
            # Call the tf.nn.relu function
            biased = tf.nn.relu(biased)
        # Return the final op
        return biased
    
def fc( x, out_size=50, is_output=False, name="fc" ):
    '''
    x is an input tensor
    Declare a name scope using the "name" parameter
    Within that scope:
      Create a W filter variable with the proper size
      Create a B bias variable with the proper size
      Multiply x by W and add b
      If is_output is False,
        Call the tf.nn.relu function
      Return the final op
    '''
    pass
    # Declare a name scope using the "name" parameter
    with tf.name_scope("fully_connected") as scope:
        m = x.get_shape().as_list()[0];
        # Create a W filter variable with the proper size
        W = tf.get_variable("W", None, dtype=float32, initializer=tf.random_normal([out_size, m]))
        # Create a B bias variable with the proper size
        B = tf.get_variable("B", None, dtype=float32, initializer=tf.random_normal([out_size, 1]))
        # Multiply x by W and add b
        mul = tf.matmul(x, W)
        my_sum = mul + B
        # If is_output is False,
        if (is_output == False):
            #Call the tf.nn.relu function
            my_sum = tf.nn.relu(my_sum)
        #Return the final op
        return my_sum
