# %% [markdown]
# # Part 1: Random Image Generation

# %%
import cairo
import numpy
import math
import random

 
# A star-shaped object. Sometimes...
class cv(object):

    points = ( 
        ( 0, 85 ), 
        ( 75, 75 ), 
        ( 100, 10 ), 
        ( 125, 75 ), 
        ( 200, 85 ),
        ( 150, 125 ), 
        ( 160, 190 ),
        ( 100, 150 ), 
        ( 40, 190 ),
        ( 50, 125 ),
        ( 0, 85 )
    )
    
# A simple function to display an image in an ipython notebook
def nbimage( data ):
    from IPython.display import display, Image
    from PIL.Image import fromarray
    from StringIO import StringIO
 
    s = StringIO()
    fromarray( data ).save( s, 'png' )
    display( Image( s.getvalue() ) )
 
WIDTH = 512
HEIGHT = 288
 
# this is a numpy buffer to hold the image data
data = numpy.zeros( (HEIGHT,WIDTH,4), dtype=numpy.uint8 )
 
# this creates a cairo context based on the numpy buffer
ims = cairo.ImageSurface.create_for_data( data, cairo.FORMAT_ARGB32, WIDTH, HEIGHT )
cr = cairo.Context( ims )

cr.set_source_rgba(0, 0, 0, 1 )
cr.rectangle(0, 0, WIDTH, HEIGHT)
cr.fill()

# Constant value to tune the opacity value
opacity_scalar = 0.3

# Generate 50 objects
for n in range (100):
    # Draw new object
    for i in range(10):
        scale = 0.01 * random.random()
        translate_x = random.randint(0, WIDTH)
        translate_y = random.randint(0, HEIGHT)
        cr.set_source_rgba(random.random(), random.random(), random.random(), opacity_scalar * random.random() )
        cr.line_to(translate_x + scale * cv.points[i][0], translate_y + scale * cv.points[i][1])
    # Fill in object
    cr.fill()

# display the image
nbimage( data )

# %% [markdown]
# # Part 2: TensorFlow

# %%
from IPython.display import Image
Image(filename="tensorflow.png")
